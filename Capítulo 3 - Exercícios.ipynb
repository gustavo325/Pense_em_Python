# %% [markdown]
# ### Exercício 3.1
#
# ##### Escreva uma função chamada right_justify, que receba uma string chamada s como parâmetro e exiba a string com espaços suficientes à frente para que a última letra da string esteja na coluna 70 da tela:
#
# ##### Dica: Use concatenação de strings e repetição. Além disso, o Python oferece uma função integrada chamada len, que apresenta o comprimento de uma string, então o valor de len('monty') é 5.

# %%
def right_justify(s):
  valor = ' ' * (70-len(s)) + s
  print(valor)

right_justify('teste')
# Out:
#                                                                  teste 70

# %% [markdown]
# ### Exercício 3.2
#
# ##### Um objeto de função é um valor que pode ser atribuído a uma variável ou passado como argumento. Por exemplo, do_twice é uma função que toma um objeto de função como argumento e o chama duas vezes:
# ##### def do_twice(f):
# #####    f()
# #####    f()

# %%
# 1- Digite este exemplo em um script e teste-o.

def do_twice(f):
  f()
  f()

def teste():
  print('teste')

do_twice(teste)
# Out:
# teste
# teste

# %%
# 2- Altere do_twice para que receba dois argumentos, um objeto de função e um valor, e chame a função duas vezes, passando o valor como um argumento.

def do_twice(f, x):
  f(x)
  f(x)

def teste(y):
  print(y)

do_twice(teste, 123)
# Out:
# 123
# 123

# %%
# 3- Copie a definição de print_twice que aparece anteriormente neste capítulo no seu script.

def print_twice(Bruce): 
  print(Bruce)
  print(Bruce)
# Out:
# Spam
# Spam
# Spam
# Spam

# %%
# 4- Use a versão alterada de do_twice para chamar print_twice duas vezes, passando 'spam' como um argumento.

do_twice(print_twice, 'Spam')
# Out:
# Spam
# Spam
# Spam
# Spam

# %%
# 5- Defina uma função nova chamada do_four que receba um objeto de função e um valor e chame a função quatro vezes, 
# passando o valor como um parâmetro. Deve haver só duas afirmações no corpo desta função, não quatro.

def do_four(f, valor):
  f(valor)
  f(valor)

do_four(print_twice, '4 vezes')
# Out:
# 4 vezes
# 4 vezes
# 4 vezes
# 4 vezes

# %% [markdown]
# ### Exercício 3.3
#
# #### Escreva uma função que desenhe uma grade como a seguinte:
#
#         + - - - - + - - - - +
#         |         |         |
#         |         |         |
#         |         |         |
#         |         |         |
#         + - - - - + - - - - +
#         |         |         |
#         |         |         |
#         |         |         |
#         |         |         |
#         + - - - - + - - - - +
# #### Dica: para exibir mais de um valor em uma linha, podemos usar uma sequência de valores separados por vírgula:
#
#
# #### print('+', '-')
# #### Por padrão, print avança para a linha seguinte, mas podemos ignorar esse comportamento e inserir um espaço no fim, desta forma:
#
#
# #### print('+', end=' ')
# ####  print('-')
# #### A saída dessas instruções é + -. Uma instrução print sem argumento termina a linha atual e vai para a próxima linha.
#
# #### Escreva uma função que desenhe uma grade semelhante com quatro linhas e quatro colunas.

# %%
def mais_esquerda(): 
  print('+', ' - ' * 4, end ='')

def mais_direita():
  print(' - ' * 4, '+', end ='')

def mais(): 
  print('+', end='')

def mais_esquerda_pula(): 
  print('+', ' - ' * 4)

def mais_direita_pula():
  print(' - ' * 4, '+')

def mais_pula(): 
  print('+')

def pipe():
  print('|', ' ' *12, end ='')

def pipe_pula(): 
  print('|')

# Criação de linha superior
mais_esquerda()
mais_esquerda()
mais_pula()

pipe()
pipe()
pipe_pula()
pipe()
pipe()
pipe_pula()
pipe()
pipe()
pipe_pula()
pipe()
pipe()
pipe_pula()
pipe()
pipe()
pipe_pula()

# Criação de linha do meio
mais_esquerda()
mais_esquerda()
mais_pula()

pipe()
pipe()
pipe_pula()
pipe()
pipe()
pipe_pula()
pipe()
pipe()
pipe_pula()
pipe()
pipe()
pipe_pula()
pipe()
pipe()
pipe_pula()

# Criação da última linha
mais_esquerda()
mais_esquerda()
mais_pula()
# Out:
# +  -  -  -  - +  -  -  -  - +
# |             |             |
# |             |             |
# |             |             |
# |             |             |
# |             |             |
# +  -  -  -  - +  -  -  -  - +
# |             |             |
# |             |             |
# |             |             |
# |             |             |
# |             |             |
# +  -  -  -  - +  -  -  -  - +
